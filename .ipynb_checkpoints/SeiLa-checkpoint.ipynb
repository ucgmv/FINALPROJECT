# %%
import os
import pandas as pd
import numpy as np
from sklearn import preprocessing,metrics 
from IPython.core.display import HTML
pd.set_option("display.max_columns",75)
import warnings
import math
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import linear_model,svm
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve

# %%
df = pd.read_excel('JPM Disposed.xlsx', skiprows = 1)

# %%
df.head()
# Out:
#    Unnamed: 0             Property\nName Trustee\nLoan ID  \
# 0         NaN              Metro Station        991072135
# 1         NaN                 The Colony        991072127
# 2         NaN  Riverwood Shopping Center        991072154
# 3         NaN         The Lehman Mansion        991072093
# 4         NaN   Woodland Park Apartments        991072097
#
#   Secur\nLoan\nBalance  DSCR     LTV Before Disposition\nBalance  \
# 0              4850000  1.19  127.59                     4059253
# 1              5800000  3.46    50.5                     4810571
# 2              3880000  1.56    72.9                     3253504
# 3              8875000   1.2      68                     6812218
# 4              8500000   1.2    78.7                     7079006
#
#   Before Disposition\nPaid Thru\nDate Before Disposition\nDefeased\nStatus  \
# 0                 2015-02-01 00:00:00                                    -
# ...

# %%
df = df.iloc[:,1:]
df.head()
# Out:
#               Property\nName Trustee\nLoan ID Secur\nLoan\nBalance  DSCR  \
# 0              Metro Station        991072135              4850000  1.19
# 1                 The Colony        991072127              5800000  3.46
# 2  Riverwood Shopping Center        991072154              3880000  1.56
# 3         The Lehman Mansion        991072093              8875000   1.2
# 4   Woodland Park Apartments        991072097              8500000   1.2
#
#       LTV Before Disposition\nBalance Before Disposition\nPaid Thru\nDate  \
# 0  127.59                     4059253                 2015-02-01 00:00:00
# 1    50.5                     4810571                 2015-02-01 00:00:00
# 2    72.9                     3253504                 2015-02-01 00:00:00
# 3      68                     6812218                 2015-02-01 00:00:00
# 4    78.7                     7079006                 2015-02-01 00:00:00
#
#   Before Disposition\nDefeased\nStatus Before Disposition\nModified\nStatus  \
# ...

# %%
print(range(df))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e5affb6905bb> in <module>
# ----> 1 print(range(df))
#
# TypeError: 'DataFrame' object cannot be interpreted as an integer

# %%
print(df.range())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a47780bc4716> in <module>
# ----> 1 print(df.range())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'range'

# %%
print('Current shape:', df.shape)
# Out:
# Current shape: (5134, 36)

# %%
df = df.dropna(axis=0, thresh = 36)

# %%
print('Current shape:', df.shape)
# Out:
# Current shape: (5134, 36)

# %%
df1 = pd.read_excel('JPM Disposed.xlsx', skiprows = 1)

# %%
print('Current shape:', df1.shape)
# Out:
# Current shape: (0, 37)

# %%
df1 = df1.dropna(axis=0, thresh = 37)

# %%
print(df)
# Out:
#                          Property\nName Trustee\nLoan ID Secur\nLoan\nBalance  \
# 0                         Metro Station        991072135              4850000
# 1                            The Colony        991072127              5800000
# 2             Riverwood Shopping Center        991072154              3880000
# 3                    The Lehman Mansion        991072093              8875000
# 4              Woodland Park Apartments        991072097              8500000
# ...                                 ...              ...                  ...
# 5165     63-65 South Street - Hopkinton        940953050              4600000
# 5166          South Sierra Plaza Retail        940952799              6500000
# 5167                      Madison Plaza         30265122              2800000
# 5168                 Addison at Wyndham        170000064             30850000
# 5169  StratReal Industrial Portfolio II       30259617_1             37200000
#
# ...

# %%
print(df[130140,:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-4f1d7de4efcc> in <module>
# ----> 1 print(df[130:140,:])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2893             casted_key = self._maybe_cast_indexer(key)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#    2897                 raise KeyError(key) from err
#
# ...

# %%
print(df1[math.isnan(df1['Trustee\nLoan ID'])])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-c9f8e897535d> in <module>
# ----> 1 print(df1[math.isnan(df1['Trustee\nLoan ID'])])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in wrapper(self)
#     127         if len(self) == 1:
#     128             return converter(self.iloc[0])
# --> 129         raise TypeError(f"cannot convert the series to {converter}")
#     130
#     131     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'float'>

# %%
math.isnan(df1['Trustee\nLoan ID'][130])
# Out:
# True

# %%
nan_df = pd.DataFrame()
i=0
for i in range(x-1):
    nan_df.append(math.isnan(df1['Trustee\nLoan ID'][i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-4ae76792a87e> in <module>
#       2 i=0
#       3 for i in range(x-1):
# ----> 4     nan_df.append(math.isnan(df1['Trustee\nLoan ID'][i]))
#       5
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7741         else:
#    7742             to_concat = [self, other]
# -> 7743         return concat(
#    7744             to_concat,
#    7745             ignore_index=ignore_index,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ...

# %%
[x,y] = df1.shape
print(x)
# Out:
# 5170
